# %%
import pandas as pd
import numpy as np
import webbrowser as wb

url='http://archieve.ics.uci.edu/ml/machine-learning-databases/wine-quality/'
wb.open(url)
# Out:
# True

# %%
df=pd.read_csv(r'F:\\csv file\winequality-red.csv',sep=';')
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
def max_to_min(arr):
    return arr.max()-arr.min()

# %%
wino=df.groupby('quality')
wino.describe()
# Out:
#         fixed acidity                                                     \
#                 count      mean       std  min   25%   50%     75%   max
# quality
# 3                10.0  8.360000  1.770875  6.7  7.15  7.50   9.875  11.6
# 4                53.0  7.779245  1.626624  4.6  6.80  7.50   8.400  12.5
# 5               681.0  8.167254  1.563988  5.0  7.10  7.80   8.900  15.9
# 6               638.0  8.347179  1.797849  4.7  7.00  7.90   9.400  14.3
# 7               199.0  8.872362  1.992483  4.9  7.40  8.80  10.100  15.6
# 8                18.0  8.566667  2.119656  5.0  7.25  8.25  10.225  12.6
#
#         volatile acidity            ... sulphates       alcohol             \
#                    count      mean  ...       75%   max   count       mean
# quality                             ...
# 3                   10.0  0.884500  ...     0.615  0.86    10.0   9.955000
# 4                   53.0  0.693962  ...     0.600  2.00    53.0  10.265094
# ...

# %%
wino.agg(max_to_min)
# Out:
#          fixed acidity  volatile acidity  citric acid  residual sugar  \
# quality
# 3                  4.9             1.140         0.66             4.5
# 4                  7.9             0.900         1.00            11.6
# 5                 10.9             1.150         0.79            14.3
# 6                  9.6             0.880         0.78            14.5
# 7                 10.7             0.795         0.76             7.7
# 8                  7.6             0.590         0.69             5.0
#
#          chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# quality
# 3            0.206                 31.0                  40.0  0.00609  0.47
# 4            0.565                 38.0                 112.0  0.00760  1.16
# 5            0.572                 65.0                 149.0  0.01059  0.86
# 6            0.381                 71.0                 159.0  0.01362  1.15
# ...

# %%
df.agg('mean')
# Out:
# fixed acidity            8.319637
# volatile acidity         0.527821
# citric acid              0.270976
# residual sugar           2.538806
# chlorides                0.087467
# free sulfur dioxide     15.874922
# total sulfur dioxide    46.467792
# density                  0.996747
# pH                       3.311113
# sulphates                0.658149
# alcohol                 10.422983
# quality                  5.636023
# dtype: float64

# %%
df['qual/alc_rat']=df['quality']/df['alcohol']
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality  qual/alc_rat
# 0      9.4        5      0.531915
# ...

# %%
df.pivot_table(index=['quality'])
# Out:
#            alcohol  chlorides  citric acid   density  fixed acidity  \
# quality
# 3         9.955000   0.122500     0.171000  0.997464       8.360000
# 4        10.265094   0.090679     0.174151  0.996542       7.779245
# 5         9.899706   0.092736     0.243686  0.997104       8.167254
# 6        10.629519   0.084956     0.273824  0.996615       8.347179
# 7        11.465913   0.076588     0.375176  0.996104       8.872362
# 8        12.094444   0.068444     0.391111  0.995212       8.566667
#
#          free sulfur dioxide        pH  qual/alc_rat  residual sugar  \
# quality
# 3                  11.000000  3.398000      0.303286        2.635000
# 4                  12.264151  3.381509      0.392724        2.694340
# 5                  16.983847  3.304949      0.507573        2.528855
# 6                  15.711599  3.318072      0.569801        2.477194
# 7                  14.045226  3.290754      0.614855        2.720603
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df.plot(kind='scatter',x='quality',y='alcohol',grid='both')
# Out:
# <Axes: xlabel='quality', ylabel='alcohol'>

# %%
df.groupby('alcohol').agg('mean')
# Out:
#            fixed acidity  volatile acidity  citric acid  residual sugar  \
# alcohol
# 8.400000       12.350000          0.460000     0.615000        1.950000
# 8.500000       10.000000          0.380000     0.380000        1.600000
# 8.700000        8.050000          0.330000     0.445000        2.100000
# 8.800000        9.900000          0.500000     0.500000       13.800000
# 9.000000        8.793333          0.586833     0.295667        3.060000
# ...                  ...               ...          ...             ...
# 13.500000       5.800000          0.290000     0.260000        1.700000
# 13.566667       5.300000          0.470000     0.110000        2.200000
# 13.600000       5.700000          0.412500     0.237500        2.525000
# 14.000000       5.657143          0.407143     0.104286        1.957143
# 14.900000      15.900000          0.360000     0.650000        7.500000
#
#            chlorides  free sulfur dioxide  total sulfur dioxide   density  \
# alcohol
# ...

# %%
df.groupby('quality').agg({'alcohol':['mean','max','sum','count'],
                           'pH':['mean','max','sum','count']})
# Out:
#            alcohol                                 pH
#               mean   max          sum count      mean   max      sum count
# quality
# 3         9.955000  11.0    99.550000    10  3.398000  3.63    33.98    10
# 4        10.265094  13.1   544.050000    53  3.381509  3.90   179.22    53
# 5         9.899706  14.9  6741.700000   681  3.304949  3.74  2250.67   681
# 6        10.629519  14.0  6781.633333   638  3.318072  4.01  2116.93   638
# 7        11.465913  14.0  2281.716667   199  3.290754  3.78   654.86   199
# 8        12.094444  14.0   217.700000    18  3.267222  3.72    58.81    18
